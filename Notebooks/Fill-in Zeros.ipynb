# %%
import pandas as pd
import numpy as np

lc_total = np.load("../../Datos_npy/koi_light_curves.npy")
lc_model_total = np.load("../../Datos_npy/koi_light_curves_model.npy")

# %%
#fullfil wih zeros
lc_total =  np.nan_to_num(lc_total)
lc_model_total =  np.nan_to_num(lc_model_total)

# %%
np.save("../../Processed_Data/koi_light_curves_full.npy",lc_total.astype("float32"))
np.save("../../Processed_Data/koi_light_curves_model_full.npy",lc_model_total.astype("float32"))

# %%
import matplotlib.pyplot as plt
plt.plot(lc_total[0])
plt.show()

# %%
plt.plot(lc_total[0,550:1050])
plt.show()
plt.plot(lc_total[0,1000:1500])
plt.show()
plt.plot(lc_total[0,1400:1900])
plt.show()

# %% [markdown]
# ### Cantidad de ceros

# %%
nan_values = []
for secuencia in df_train.values:
    nan_values.append(np.sum(np.isnan(secuencia)))
for secuencia in df_val.values:
    nan_values.append(np.sum(np.isnan(secuencia)))
for secuencia in df_test.values:
    nan_values.append(np.sum(np.isnan(secuencia)))      
print("Cantidad de nans por secuencia",np.mean(nan_values))
print("Porcentaje de nans por secuencia",np.mean(nan_values)/len(secuencia))
# Out:
# Cantidad de nans por secuencia 16417.8890842
# Porcentaje de nans por secuencia 0.229855504
