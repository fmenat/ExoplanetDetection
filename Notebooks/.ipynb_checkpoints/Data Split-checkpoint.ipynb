# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %%
data=pd.read_csv("../Datos/koi_metadata.csv") #without error
data.fillna(data.median(), inplace=True)
data.head()
# Out:
#     KOI Name NExScI Disposition  Kepler Name      Period  \
# 0  K00889.01          CONFIRMED  Kepler-75 b    8.884923
# 1  K01009.01     FALSE POSITIVE          NaN    5.092465
# 2  K07621.01     FALSE POSITIVE          NaN  275.073650
# 3  K06252.01     FALSE POSITIVE          NaN    8.460439
# 4  K00958.01          CANDIDATE          NaN   21.761298
#
#    Time of Transit Epoch  First Transit Time (BJD)  Impact Parameter  \
# 0             169.991686               2455002.992             0.069
# 1             357.535940               2455190.536             0.161
# 2             315.248600               2455148.249             0.595
# 3             133.774490               2454966.774             1.061
# 4             166.540438               2454999.540             0.123
#
#    Duration  Transit Depth    r/R       ...          Teff  log(g)  \
# 0   2.07004        16053.4  0.114       ...        5332.0   4.500
# 1   3.65900          254.0  0.014       ...        5037.0   4.547
# 2   3.37000          228.9  0.014       ...        5604.0   4.226
# 3   4.73492        76412.9  0.478       ...        5951.0   4.638
# 4   1.24300         1300.7  0.032       ...        4859.0   4.612
#
#    Metallicity  Stellar Radius  Stellar Mass  Max single event sigma  \
# 0        -0.08           0.843         0.821                  61.291
# 1        -0.20           0.751         0.727                   3.648
# 2        -0.12           1.187         0.864                   5.909
# 3        -1.06           0.702         0.796                 452.526
# 4         0.00           0.720         0.781                  19.204
#
#    Max Multievent sigma  Transit Model SNR  KOI count  Transit Number
# 0               474.021              388.2          1             153
# 1                15.175               17.1          1             225
# 2                 8.012                7.5          1               4
# 3              3704.503             1797.4          1             164
# 4                96.205               60.0          1              62
#
# [5 rows x 31 columns]

# %%
data.shape
# Out:
# (8054, 31)

# %%
sns.countplot(x='NExScI Disposition',data=data)
plt.title('Kepler Object Disposition')
plt.show()

# %%
c=Counter(data['NExScI Disposition'])

# %%
fp=c['FALSE POSITIVE']
con=c['CONFIRMED']

# %%
np.asarray([con,fp])*(1.0/np.sum(con+fp))
# Out:
# array([0.3645517, 0.6354483])

# %%
from sklearn.decomposition import PCA,KernelPCA
from sklearn.preprocessing import StandardScaler

data_num=X=data.iloc[:,3:]
escalado = StandardScaler().fit_transform(data_num)
pca = PCA(n_components=2)
pca.fit(escalado)
escalado2 = pca.transform(escalado)

# %%
from sklearn.decomposition import PCA,KernelPCA

escalado_kpca = KernelPCA(kernel="rbf",n_components=2,fit_inverse_transform=True, gamma=0.5).fit_transform(escalado)

# %%
escalado_kpca[:10]
# Out:
# array([[-0.00661963, -0.35342583],
#        [ 0.11586561,  0.02884765],
#        [ 0.11399678,  0.02807522],
#        [ 0.11456376,  0.02909658],
#        [ 0.11353049,  0.02787084],
#        [ 0.11306984,  0.01466558],
#        [ 0.11372627,  0.02796399],
#        [ 0.12005299,  0.02324064],
#        [ 0.06738396, -0.25063014],
#        [ 0.11447176,  0.02826237]])

# %%
dict_disp=dict()
i=0
for reg in data['NExScI Disposition'].values:
    if reg not in dict_disp:
        dict_disp[reg]=[i]
    else:
        dict_disp[reg].append(i)
    i+=1

# %%
dict_disp.keys()
# Out:
# ['CONFIRMED', 'FALSE POSITIVE', 'CANDIDATE']

# %%
mask = data["NExScI Disposition"]=='CANDIDATE'

# %%
plt.figure(figsize=(10,6))
plt.scatter(escalado2[:,0], escalado2[:,1],label="Labeled object",color='b',alpha=0.95)
plt.scatter(escalado2[mask][:,0], escalado2[mask][:,1],label="Candidate",color='cyan',alpha=0.4)
#plt.title('Todas los objetos')
plt.legend(loc='upper left')
plt.show()

# %%
from sklearn.cluster import SpectralClustering, DBSCAN, KMeans, Birch

# %%
clustering = SpectralClustering(n_clusters=3, assign_labels="discretize").fit(escalado2)
clustering_cand = SpectralClustering(n_clusters=3, assign_labels="discretize").fit(escalado2[mask])

# %%
clustering
# Out:
# SpectralClustering(affinity='rbf', assign_labels='discretize', coef0=1,
#           degree=3, eigen_solver=None, eigen_tol=0.0, gamma=1.0,
#           kernel_params=None, n_clusters=3, n_init=10, n_jobs=1,
#           n_neighbors=10, random_state=None)

# %%
colormap = np.array(['red', 'lime', 'blue','grey','yellow','brown','pink','black','purple','olive','emerald','crimson'])
plt.figure(figsize=(10,6))
plt.scatter(escalado2[:,0], escalado2[:,1], c=colormap[clustering.labels_])
plt.title('KOI spectral clustering')
plt.show()

# %%
colormap = np.array(['red', 'lime', 'blue','grey','yellow','brown','pink','black','purple','olive','emerald','crimson'])
plt.figure(figsize=(10,6))
plt.scatter(escalado2[mask][:,0], escalado2[mask][:,1], c=colormap[clustering_cand.labels_])
plt.title('KOI spectral clustering')
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=0).fit(escalado2)
print (kmeans.labels_)
kmeans_cand = KMeans(n_clusters=3, random_state=0).fit(escalado2[mask])
kmeans_cand.labels_
# Out:
# [1 1 2 ... 1 1 1]
# array([2, 2, 0, ..., 0, 2, 2], dtype=int32)

# %%
print (kmeans.cluster_centers_)
kmeans_cand.cluster_centers_
# Out:
# [[-1.69656596  3.68711136]
#  [-0.33126559 -0.63209112]
#  [ 5.26519254  1.33074688]]
# array([[-0.36280332, -0.77636488],
#        [ 6.52988084,  1.80901787],
#        [ 2.04241631, -0.11916024]])

# %%
colormap = np.array(['red', 'lime', 'blue','grey','yellow','black','purple','olive'])
plt.figure(figsize=(10,6))
plt.scatter(escalado2[:,0], escalado2[:,1], c=colormap[kmeans.labels_])
plt.title('KOI Kmeans')
plt.show()

# %%
colormap = np.array(['red', 'lime', 'blue','grey','yellow','black','purple','olive'])
plt.figure(figsize=(10,6))
plt.scatter(escalado2[mask][:,0], escalado2[mask][:,1], c=colormap[kmeans_cand.labels_])
plt.title('KOI Candidates Kmeans')
plt.show()

# %%
brc = Birch(branching_factor=50, n_clusters=5, threshold=0.5,compute_labels=True).fit(escalado2)
brc_cand = Birch(branching_factor=50, n_clusters=5, threshold=0.5,compute_labels=True).fit(escalado2[mask])
# Out:
# /users/mbugueno/anaconda2/lib/python2.7/site-packages/sklearn/cluster/birch.py:77: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   node1_dist, node2_dist = dist[[farthest_idx]]

# %%
colormap = np.array(['red', 'lime', 'blue','grey','yellow','black','purple','olive'])
plt.figure(figsize=(10,6))
plt.scatter(escalado2[:,0], escalado2[:,1], c=colormap[brc.labels_])

plt.title('KOI Birch')
plt.show()

# %%
colormap = np.array(['red', 'lime', 'blue','grey','yellow','black','purple','olive'])
plt.figure(figsize=(10,6))
plt.scatter(escalado2[mask][:,0], escalado2[mask][:,1], c=colormap[brc_cand.labels_])
plt.title('KOI Birch')
plt.show()

# %%
from sklearn.cluster import MiniBatchKMeans

mbk=MiniBatchKMeans(n_clusters=3,random_state=0,batch_size=6).fit(escalado2)
mbk_cand=MiniBatchKMeans(n_clusters=3,random_state=0,batch_size=6).fit(escalado2[mask])

# %%
colormap = np.array(['red', 'lime', 'blue','grey','yellow','black','purple','olive','green'])
plt.figure(figsize=(10,6))
plt.scatter(escalado2[:,0], escalado2[:,1], c=colormap[mbk.labels_])
plt.title('KOI Mini Batch Kmeans')
plt.show()

# %%
colormap = np.array(['red', 'lime', 'blue','grey','yellow','black','purple','olive','green'])
plt.figure(figsize=(10,6))
plt.scatter(escalado2[mask][:,0], escalado2[mask][:,1], c=colormap[mbk_cand.labels_])
plt.scatter(mbk_cand.cluster_centers_[:,0],mbk_cand.cluster_centers_[:,1],c='black')
plt.title('KOI Mini Batch Kmeans')
plt.show()

# %%
def distancia_minima(centroides,punto):
    distancias=[]
    for centroide in centroides:
        distancias.append(np.sqrt((centroide[0]-punto[0])**2+(centroide[1]-punto[1])**2))
    return min(distancias)

# %%
index_dis=[]
for i in range(len(escalado2)):
    if not mask[i]:
        punto=escalado2[i]
        index_dis.append((i,distancia_minima(mbk_cand.cluster_centers_,punto)))

# %%
index_dis.sort(key=lambda x: x[1])

# %%
index_val=np.asarray(index_dis)[:,0][int(len(index_dis)*0.25):int(len(index_dis)*0.50)]
index_train1=np.asarray(index_dis)[:,0][:int(len(index_dis)*0.25)]
index_train2=np.asarray(index_dis)[:,0][int(len(index_dis)*0.50):]

# %%
index_val[:10]
# Out:
# array([1554.,  746., 6876., 6256., 6121., 1754., 7014.,  679., 3433.,
#        7581.])

# %%
len(index_val)
# Out:
# 1564

# %%
index_train=np.asarray(list(index_train1)+list(index_train2))

# %%
len(index_train)
# Out:
# 4693

# %%
len(np.asarray(index_dis)[:,0])
# Out:
# 6257

# %%
t=pd.read_csv("../Datos/koi_sets.csv")
t.shape

temp=[]
for i in range(len(t)):
    if i in index_train:
        temp.append("Train")
    elif i in index_val:
        temp.append("Test")
    else:
        temp.append("Unlabeled")

# %%
df = pd.DataFrame()
df["KOI Name"] = data["KOI Name"]
df["Set"] = temp
df.head()
# Out:
#     KOI Name        Set
# 0  K00889.01       Test
# 1  K01009.01      Train
# 2  K07621.01      Train
# 3  K06252.01      Train
# 4  K00958.01  Unlabeled

# %%
df.to_csv("koi_sets_aux.csv",index=False)

# %%
df_sets = pd.read_csv("koi_sets_aux.csv")
mask_train = (df_sets["Set"] == "Train").values
mask_test = (df_sets["Set"] == "Test").values
df_meta = pd.read_csv("../Datos/koi_metadata.csv")

# %%
df_meta_train = df_meta[mask_train] 
df_meta_test = df_meta[mask_test]
y_train = ((df_meta_train["NExScI Disposition"]=="CONFIRMED")*1).values
y_test = ((df_meta_test["NExScI Disposition"]=="CONFIRMED")*1).values

# %%
# %matplotlib inline
plt.figure(figsize=(10,6))
plt.title("TRAIN ")
plt.bar(0, np.sum(y_train==1),color="blue")
plt.bar(1, np.sum(y_train==0),color="green")
plt.xticks([0,1],["CONFIRMED","FALSE POSITIVE"])
plt.ylabel("Count")
# Out:
# Text(0,0.5,'Count')

# %%
plt.figure(figsize=(10,6))
plt.title("TEST ")
plt.bar(0, np.sum(y_test==1),color="blue")
plt.bar(1, np.sum(y_test==0),color="green")
plt.xticks([0,1],["CONFIRMED","FALSE POSITIVE"])
plt.ylabel("Count")
# Out:
# Text(0,0.5,'Count')

# %%
mask_train
# Out:
# array([False,  True,  True, ...,  True, False,  True])

# %%
mask
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
# 5        True
# 6       False
# 7       False
# 8        True
# 9       False
# 10      False
# 11       True
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18       True
# 19       True
# 20       True
# 21      False
# 22      False
# 23      False
# 24       True
# 25       True
# 26      False
# 27       True
# 28      False
# 29      False
#         ...
# 8024    False
# 8025     True
# 8026     True
# 8027    False
# 8028     True
# 8029    False
# 8030    False
# 8031    False
# 8032    False
# 8033    False
# 8034    False
# 8035    False
# 8036     True
# 8037    False
# 8038    False
# 8039     True
# 8040     True
# 8041    False
# 8042    False
# 8043    False
# 8044    False
# 8045    False
# 8046     True
# 8047    False
# 8048    False
# 8049     True
# 8050    False
# 8051    False
# 8052     True
# 8053    False
# Name: NExScI Disposition, Length: 8054, dtype: bool

# %%
colormap = np.array(['red', 'lime', 'blue','grey','yellow','black','purple','olive','green'])
plt.figure(figsize=(10,6))
plt.scatter(escalado2[mask_test][:,0], escalado2[mask_test][:,1])
#plt.scatter(escalado2[mask_train][:,0], escalado2[mask_train][:,1])
plt.title('KOIdffgfeans')
plt.show()

# %%
#region
index_ventana=np.asarray(index_dis)[:,0][:int(len(index_dis)*0.80)]#[int(len(index_dis)*0.15):int(len(index_dis)*0.70)]
len(index_ventana)
# Out:
# 5005

# %%
import random
random.shuffle(index_ventana)

# %%
new_train=[]
new_val=[]
for reg in index_ventana:#dict_disp['CANDIDATE']:
    if len(new_val)<1565:
        if reg in dict_disp['FALSE POSITIVE']:
            if np.random.rand() <= 0.6354483:
                new_val.append(reg)
            else:
                new_train.append(reg)
        if reg in dict_disp['CONFIRMED']:
            if np.random.rand() <= 0.3645517:
                new_val.append(reg)
            else:
                new_train.append(reg)
    else:
        new_train.append(reg)

# %%
len(new_val)
# Out:
# 1565

# %%
len(new_train)
# Out:
# 3440

# %%
for reg in np.asarray(index_dis)[:,0]:
    if reg not in index_ventana:
        new_train.append(reg)
len(new_train)
# Out:
# 4692

# %%
temp=[]
for i in range(len(t)):
    if i in new_train:
        temp.append("Train")
    elif i in new_val:
        temp.append("Test")
    else:
        temp.append("Unlabeled")
        
df = pd.DataFrame()
df["KOI Name"] = data["KOI Name"]
df["Set"] = temp
df.head()
# Out:
#     KOI Name        Set
# 0  K00889.01       Test
# 1  K01009.01      Train
# 2  K07621.01      Train
# 3  K06252.01      Train
# 4  K00958.01  Unlabeled

# %%
df.shape
# Out:
# (8054, 2)

# %%
df.to_csv("../Datos/koi_sets_unb.csv",index=False)

# %%
import pandas as pd
df_sets = pd.read_csv("../Datos/koi_sets_unb.csv")
mask_train = (df_sets["Set"] == "Train").values
mask_test = (df_sets["Set"] == "Test").values
df_meta = pd.read_csv("../Datos/koi_metadata.csv")

df_meta_train = df_meta[mask_train] 
df_meta_test = df_meta[mask_test]
y_train = ((df_meta_train["NExScI Disposition"]=="CONFIRMED")*1).values
y_test = ((df_meta_test["NExScI Disposition"]=="CONFIRMED")*1).values

# %%
# %matplotlib inline
plt.figure(figsize=(10,6))
plt.title("TRAIN ")
plt.bar(0, np.sum(y_train==1),color="blue")
plt.bar(1, np.sum(y_train==0),color="green")
plt.xticks([0,1],["CONFIRMED","FALSE POSITIVE"])
plt.ylabel("Count")
# Out:
# Text(0,0.5,'Count')

# %%
plt.figure(figsize=(10,6))
plt.title("TEST ")
plt.bar(0, np.sum(y_test==1),color="blue")
plt.bar(1, np.sum(y_test==0),color="green")
plt.xticks([0,1],["CONFIRMED","FALSE POSITIVE"])
plt.ylabel("Count")
# Out:
# Text(0,0.5,'Count')

# %%
colormap = np.array(['red', 'lime', 'blue','grey','yellow','black','purple','olive','green'])
plt.figure(figsize=(10,6))
plt.scatter(escalado2[mask_test][:,0], escalado2[mask_test][:,1])

plt.scatter(escalado2[mask_train][:,0], escalado2[mask_train][:,1])

plt.title('KOIdffgfeans')
plt.show()
