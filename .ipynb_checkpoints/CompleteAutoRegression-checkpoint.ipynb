# %%
import numpy as np
import pandas as pd
lc = np.load("../Datos_npy/koi_light_curves.npy")
df_label = pd.read_csv("Datos/koi_metadata.csv")
lc.shape
# Out:
# (8054, 71427)

# %% [markdown]
# ### Visualización
# ---

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from astropy.table import Table

# %%
print("Confirmed:")
mask = (df_label["NExScI Disposition"]=="CONFIRMED").values
conf_lc= lc[mask]
fig, ax = plt.subplots(10, 4, figsize = (12, 16))
for i in range(40):
    j = np.random.randint(0,conf_lc.shape[0])
    ax[i//4, i%4].plot(conf_lc[j])
    ax[i//4, i%4].get_xaxis().set_ticks([])
plt.show()
# Out:
# Confirmed:
# /users/fmena/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
print("False Positive:")
mask = (df_label["NExScI Disposition"]!="CONFIRMED").values
fp_lc= lc[mask]
fig, ax = plt.subplots(10, 4, figsize = (12, 16))
for i in range(40):
    j = np.random.randint(0,fp_lc.shape[0])
    ax[i//4, i%4].plot(fp_lc[j])
    ax[i//4, i%4].get_xaxis().set_ticks([])
plt.show()
# Out:
# False Positive:
# /users/fmena/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
print("Estadisticos base ")
t = Table()
t["Type"] = ["Confirmed","False Positive"]
t["Minimum"] = [np.nanmin(conf_lc),np.nanmin(fp_lc)]
t["Maximum"] = [np.nanmax(conf_lc),np.nanmax(fp_lc)]
t["Mean"] = [np.nanmean(conf_lc),np.nanmean(fp_lc)]
t
# Out:
# Estadisticos base
# <Table length=2>
#      Type       Minimum  Maximum     Mean
#     str14       float32  float32   float32
# -------------- --------- -------- ----------
#      Confirmed  -405.188  1402.38 -0.0107394
# False Positive -251832.0 233332.0  -0.165099

# %%
def autocorr(x):
    result = np.correlate(x, x, mode='full')
    return result[result.size/2:]

plt.plot(conf_lc[0])
plt.show()
plt.plot(autocorr(conf_lc[0]))
plt.show()
# Out:
# /users/fmena/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /users/fmena/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:3: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   app.launch_new_instance()

# %%
#fullfil wih zeros= nan_to_num np.nan_to_num(fp_lc[0])
conf_lc.shape
# Out:
# (2281, 71427)

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import DotProduct, WhiteKernel
kernel = DotProduct() + WhiteKernel()
gpr = GaussianProcessRegressor(kernel=None, random_state=0)
gpr.fit(np.arange(conf_lc.shape[1]).reshape(-1,1), np.nan_to_num(conf_lc[0]).reshape(-1,1))

#>>> gpr.predict(X[:2,:], return_std=True)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# /users/fmena/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result)
#    2880                 #rprint('Running code', repr(code_obj)) # dbg
# -> 2881                 exec(code_obj, self.user_global_ns, self.user_ns)
#    2882             finally:
#
# <ipython-input-37-1117e2e8f9d6> in <module>()
#       4 gpr = GaussianProcessRegressor(kernel=None, random_state=0)
# ----> 5 gpr.fit(np.arange(conf_lc.shape[1]).reshape(-1,1), np.nan_to_num(conf_lc[0]).reshape(-1,1))
#       6
#
# /users/fmena/.local/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py in fit(self, X, y)
#     254             self.log_marginal_likelihood_value_ = \
# --> 255                 self.log_marginal_likelihood(self.kernel_.theta)
#     256
#
# ...

# %%
#crearlas..
def create_dataset(secuencia,lag =1): 
    #preprocesamiento asumiendo dataset es una secuencia
    dataX = []
    dataY =[]
    for t_plus_1 in range(lag,len(secuencia)):
        if any(np.isnan( secuencia[t_plus_1-lag:t_plus_1+1])):
            continue
        #se crea el Y (target)
        predecir = secuencia[t_plus_1]
        dataY+= [predecir]
        
        #se crea el X (inputs) columnas para predecir Y
        columnasX = []
        for i in np.arange(lag,0,-1): #para los valores anteriores al t_plus_1 durante un lag
            columnasX += [secuencia[t_plus_1-i]]
        dataX.append(columnasX)
    return np.array(dataX),np.array(dataY)

def create_dataset_nan(secuencia,lag =1): 
    #preprocesamiento asumiendo dataset es una secuencia
    dataX = []
    dataY =[]
    for t_plus_1 in range(lag,len(secuencia)):
        if any(np.isnan( secuencia[t_plus_1-lag:t_plus_1+1])):
            continue
        #se crea el Y (target)
        predecir = secuencia[t_plus_1]
        dataY+= [predecir]
        
        #se crea el X (inputs) columnas para predecir Y
        columnasX = []
        for i in np.arange(lag,0,-1): #para los valores anteriores al t_plus_1 durante un lag
            columnasX += [secuencia[t_plus_1-i]]
        dataX.append(columnasX)
    return np.array(dataX),np.array(dataY)

A,B = create_dataset(conf_lc[0],3)
A
# Out:
# array([[ -0.70696998,  -1.70476997,  -0.67684001],
#        [ -1.70476997,  -0.67684001,  -1.28781998],
#        [ -0.67684001,  -1.28781998,  -1.55239999],
#        ...,
#        [  1.58799005,   1.05061996,   0.50755   ],
#        [  1.05061996,   0.50755   ,   0.76599997],
#        [  0.50755   ,   0.76599997, -12.9179697 ]], dtype=float32)

# %%
np.nan_to_num(fp_lc[0,])
# Out:
# array([ 0.        ,  0.        ,  0.        , ...,  0.20453   ,
#         0.92623001,  1.49442995], dtype=float32)

# %%
lag = 3
new_lc = conf_lc[0].copy()
for t_plus_1 in range(0,len(new_lc)):
    if t_plus_1 < lag:
        new_lc[t_plus_1] = np.nan_to_num(new_lc[t_plus_1]) #fill zeros..
    else:
        if np.isnan(new_lc[t_plus_1]):
            #rellenar
            train = new_lc[t_plus_1-lag:t_plus_1].reshape(1,-1)
            new_lc[t_plus_1] = kr.predict(train)
        else:
            new_lc[t_plus_1] = new_lc[t_plus_1]
new_lc.shape
# Out:
# (71427,)

# %%
new_lc.shape
# Out:
# (71427,)

# %%
# %%time
from sklearn.kernel_ridge import KernelRidge
kr = KernelRidge(kernel='linear')
kr.fit(A,B)
# Out:
# CPU times: user 26min 54s, sys: 20.6 s, total: 27min 14s
# Wall time: 1min 49s

# %%
# Out:
# True

# %%
plt.plot(conf_lc[0])
plt.show()
plt.plot(new_lc[27000:30000])
plt.show()
# Out:
# /users/fmena/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
