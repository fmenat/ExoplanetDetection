# %%
from astropy.io import fits
#hdulist = fits.open("Curvas/kplr005301750-20160128150956_dvt.fits")

hdulist = fits.open("Curvas/kplr008397947-20160128150956_dvt.fits",mmep=True)
hdulist.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-f6cfaf222e19> in <module>()
#       2 #hdulist = fits.open("Curvas/kplr005301750-20160128150956_dvt.fits")
#       3
# ----> 4 hdulist = fits.open("Curvas/kplr008397947-20160128150956_dvt.fits",mmep=True)
#       5 hdulist.info()
#
# /etc/anaconda3/lib/python3.6/site-packages/astropy/io/fits/hdu/hdulist.py in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     164
#     165     return HDUList.fromfile(name, mode, memmap, save_backup, cache,
# --> 166                             lazy_load_hdus, **kwargs)
#     167
#     168
#
# /etc/anaconda3/lib/python3.6/site-packages/astropy/io/fits/hdu/hdulist.py in fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     402         return cls._readfrom(fileobj=fileobj, mode=mode, memmap=memmap,
# ...

# %%
hdulist[1].header["TEPOCH"]
# Out:
# 133.9458733808316

# %%
hdulist[1].header["TDEPTH"]
# Out:
# 188.765260455455

# %%
hdulist[2].header["TEPOCH"]
# Out:
# 147.66174170517274

# %%
hdulist[2].header["TDEPTH"]
# Out:
# 442.2008794609068

# %%
hdulist[2].header
# Out:
# XTENSION= 'BINTABLE'           / marks the beginning of a new HDU
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   44 / length of first array dimension
# NAXIS2  =                71427 / length of second array dimension
# PCOUNT  =                    0 / group parameter count (not used)
# GCOUNT  =                    1 / group count (not used)
# TFIELDS =                   10 / number of table fields
# TTYPE1  = 'TIME    '           / column title: data time stamps
# TFORM1  = 'D       '           / column format: 64-bit floating point
# TUNIT1  = 'BJD - 2454833'      / column units: barycenter corrected JD
# TDISP1  = 'D14.7   '           / column display format
# TTYPE2  = 'TIMECORR'           / column title: Barycenter correction applied to
# TFORM2  = 'E       '           / column format: 32-bit floating point
# TUNIT2  = 'd       '           / column units: day
# ...

# %%
hdulist[1].data.columns
# Out:
# ColDefs(
#     name = 'TIME'; format = 'D'; unit = 'BJD - 2454833'; disp = 'D14.7'
#     name = 'TIMECORR'; format = 'E'; unit = 'd'; disp = 'E13.6'
#     name = 'CADENCENO'; format = 'J'; disp = 'I10'
#     name = 'PHASE'; format = 'E'; unit = 'days'; disp = 'E14.7'
#     name = 'LC_INIT'; format = 'E'; unit = 'dimensionless'; disp = 'E14.7'
#     name = 'LC_INIT_ERR'; format = 'E'; unit = 'dimensionless'; disp = 'E14.7'
#     name = 'LC_WHITE'; format = 'E'; unit = 'dimensionless'; disp = 'E14.7'
#     name = 'LC_DETREND'; format = 'E'; unit = 'dimensionless'; disp = 'E14.7'
#     name = 'MODEL_INIT'; format = 'E'; unit = 'dimensionless'; disp = 'E14.7'
#     name = 'MODEL_WHITE'; format = 'E'; unit = 'dimensionless'; disp = 'E14.7'
# )

# %%
hdulist[1].data["TIME"]
# Out:
# array([  131.51202993,   131.53246463,   131.55289922, ...,  1590.96003786,
#         1590.9804723 ,  1591.00090694])

# %%
hdulist[1].data["TIME"]
# Out:
# array([  131.51196429,   131.53239858,   131.55283278, ...,  1590.96049458,
#         1590.98092865,  1591.00136291])

# %%
#data = hdulist[1].data
data["LC_WHITE"].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-701c139bee69> in <module>()
#       1 #data = hdulist[1].data
# ----> 2 data["LC_WHITE"].shape
#
# NameError: name 'data' is not defined

# %%
del hdulist[1].data
del data

# %%
hdulist.close()

# %%
dato1 = hdulist[1].data["LC_WHITE"]
dato2 = hdulist[2].data["LC_WHITE"]
dato3 = hdulist[3].data["LC_WHITE"]
dato4 = hdulist[4].data["LC_WHITE"]
dato5 = hdulist[5].data["LC_WHITE"]

# %%
dato1["LC_WHITE"]
# Out:
# array([ 0.78769642, -1.64746594,  0.85239798, ..., -0.04898532,
#         1.78993237, -0.8240056 ], dtype=float32)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,8))
plt.plot(dato1[500:1000],label="Objeto 1")
plt.plot(dato2[500:1000],label="Objeto 2")
plt.plot(dato3[500:1000],label="Objeto 3")
plt.plot(dato4[500:1000],label="Objeto 4")
#plt.plot(dato5[500:1000],label="Objeto 5")
plt.legend()
plt.show()
