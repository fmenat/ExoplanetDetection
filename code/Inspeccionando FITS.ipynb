# %%
from astropy.io import fits
import matplotlib.pyplot as plt

folder = "/media/fmena/Datos/"

# %%
hdulist = fits.open(folder+'Curvas/kplr000757450-20160128150956_dvt.fits')
#hdulist = fits.open(folder+'Curvas/kplr002013883-20160128150956_dvt.fits')

hdulist.info()
# Out:
# Filename: /media/fmena/Datos/Curvas/kplr000757450-20160128150956_dvt.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      56   ()
#   1  TCE_1         1 BinTableHDU    106   71427R x 10C   [D, E, J, E, E, E, E, E, E, E]
#   2  Statistics    1 BinTableHDU    221   71427R x 50C   [D, E, J, E, E, E, E, J, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E]

# %%
# !ls
# Out:
# AstroInf		   kplr000757450-20160128150956_dvt.fits
# Inspeccionando FITS.ipynb  kplr002013883-20160128150956_dvt.fits

# %%
hdulist[1].header
# Out:
# XTENSION= 'BINTABLE'           / marks the beginning of a new HDU
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   44 / length of first array dimension
# NAXIS2  =                71427 / length of second array dimension
# PCOUNT  =                    0 / group parameter count (not used)
# GCOUNT  =                    1 / group count (not used)
# TFIELDS =                   10 / number of table fields
# TTYPE1  = 'TIME    '           / column title: data time stamps
# TFORM1  = 'D       '           / column format: 64-bit floating point
# TUNIT1  = 'BJD - 2454833'      / column units: barycenter corrected JD
# TDISP1  = 'D14.7   '           / column display format
# TTYPE2  = 'TIMECORR'           / column title: Barycenter correction applied to
# TFORM2  = 'E       '           / column format: 32-bit floating point
# TUNIT2  = 'd       '           / column units: day
# ...

# %%
data = hdulist[1].data
time = data.field('TIME')

# %%
time
# Out:
# array([  131.51266094,   131.53309564,   131.55353023, ...,  1590.96061377,
#         1590.9810483 ,  1591.00148304])

# %%
import numpy as np
np.isnan(lc_init).any()
# Out:
# True

# %%
lc_init = data.field("LC_INIT")
plt.plot(lc_init[10:1000])
plt.title("Quarter stitched initial light cu")
plt.show()

# %%
lc_whitemodel = data.field("LC_INIT_ERR")

plt.plot(lc_whitemodel[10:1000])
plt.title("Quarter stitched initial light curve ERROR")
plt.show()

# %%
np.count_nonzero(np.isnan(lc_white))
# Out:
# 6989

# %%
lc_white = data.field("LC_WHITE")

plt.plot(lc_white[10:1000])
plt.title("Initial whitened time series fit")
plt.show()

# %%
lc_detrend = data.field("LC_DETREND")

plt.plot(lc_detrend[10:1000])
plt.title("Initial median detrended time ser")
plt.show()

# %%
np.isnan(lc_model).any()
# Out:
# False

# %%
lc_model = data.field("MODEL_INIT")

plt.plot(lc_model[10:1000])
plt.title("Model light curve")
plt.show()

# %%
lc_whitemodel = data.field("MODEL_WHITE")

plt.plot(lc_whitemodel[10:1000])
plt.title("Whitened Model light curve")
plt.show()

# %%
hdulist = fits.open(folder+"Curvas/kplr005301750-20160128150956_dvt.fits")

#hdulist = fits.open(folder+"Curvas/kplr008397947-20160128150956_dvt.fits",mmep=True)
hdulist.info()
# Out:
# Filename: /media/fmena/Datos/Curvas/kplr005301750-20160128150956_dvt.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      56   ()
#   1  TCE_1         1 BinTableHDU    106   71427R x 10C   [D, E, J, E, E, E, E, E, E, E]
#   2  TCE_2         1 BinTableHDU    106   71427R x 10C   [D, E, J, E, E, E, E, E, E, E]
#   3  TCE_3         1 BinTableHDU    106   71427R x 10C   [D, E, J, E, E, E, E, E, E, E]
#   4  TCE_4         1 BinTableHDU    106   71427R x 10C   [D, E, J, E, E, E, E, E, E, E]
#   5  TCE_5         1 BinTableHDU    106   71427R x 10C   [D, E, J, E, E, E, E, E, E, E]
#   6  Statistics    1 BinTableHDU    221   71427R x 50C   [D, E, J, E, E, E, E, J, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E]

# %%
hdulist[1].header["TEPOCH"]
# Out:
# 133.9458733808316

# %%
hdulist[1].header["TDEPTH"]
# Out:
# 188.765260455455

# %%
hdulist[2].header
# Out:
# XTENSION= 'BINTABLE'           / marks the beginning of a new HDU
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   44 / length of first array dimension
# NAXIS2  =                71427 / length of second array dimension
# PCOUNT  =                    0 / group parameter count (not used)
# GCOUNT  =                    1 / group count (not used)
# TFIELDS =                   10 / number of table fields
# TTYPE1  = 'TIME    '           / column title: data time stamps
# TFORM1  = 'D       '           / column format: 64-bit floating point
# TUNIT1  = 'BJD - 2454833'      / column units: barycenter corrected JD
# TDISP1  = 'D14.7   '           / column display format
# TTYPE2  = 'TIMECORR'           / column title: Barycenter correction applied to
# TFORM2  = 'E       '           / column format: 32-bit floating point
# TUNIT2  = 'd       '           / column units: day
# ...

# %%
hdulist[1].data.columns
# Out:
# ColDefs(
#     name = 'TIME'; format = 'D'; unit = 'BJD - 2454833'; disp = 'D14.7'
#     name = 'TIMECORR'; format = 'E'; unit = 'd'; disp = 'E13.6'
#     name = 'CADENCENO'; format = 'J'; disp = 'I10'
#     name = 'PHASE'; format = 'E'; unit = 'days'; disp = 'E14.7'
#     name = 'LC_INIT'; format = 'E'; unit = 'dimensionless'; disp = 'E14.7'
#     name = 'LC_INIT_ERR'; format = 'E'; unit = 'dimensionless'; disp = 'E14.7'
#     name = 'LC_WHITE'; format = 'E'; unit = 'dimensionless'; disp = 'E14.7'
#     name = 'LC_DETREND'; format = 'E'; unit = 'dimensionless'; disp = 'E14.7'
#     name = 'MODEL_INIT'; format = 'E'; unit = 'dimensionless'; disp = 'E14.7'
#     name = 'MODEL_WHITE'; format = 'E'; unit = 'dimensionless'; disp = 'E14.7'
# )

# %%
hdulist[1].data["TIME"]
# Out:
# array([ 131.51162442,  131.53205904,  131.55249357, ..., 1590.95976281,
#        1590.98019712, 1591.00063164])

# %%
dato1 = hdulist[1].data["LC_WHITE"]
dato2 = hdulist[2].data["LC_WHITE"]
dato3 = hdulist[3].data["LC_WHITE"]
dato4 = hdulist[4].data["LC_WHITE"]
dato5 = hdulist[5].data["LC_WHITE"]

# %%
ini = 400
finit = 1600

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(16,8))
plt.plot(dato1[ini:finit],label="Objeto 1",c='b')
plt.plot(dato2[ini:finit],label="Objeto 2",c='r')
plt.plot(dato3[ini:finit],label="Objeto 3",c='g')
plt.plot(dato4[ini:finit],label="Objeto 4",c='m')
#plt.plot(dato5[500:1000],label="Objeto 5")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.plot(dato1[ini:finit]+dato2[ini:finit]+dato3[ini:finit]+dato4[ini:finit])
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.plot(dato1[ini:finit],c='b')
plt.show()
plt.figure(figsize=(16,8))
plt.plot(dato2[ini:finit],c='r')
plt.show()
plt.figure(figsize=(16,8))
plt.plot(dato3[ini:finit],c='g')
plt.show()
plt.figure(figsize=(16,8))
plt.plot(dato4[ini:finit],c='m')
plt.show()
