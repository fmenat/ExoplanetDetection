# %% [markdown]
# ## sobre fourier

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
import csv
import pandas as pd


std = StandardScaler(with_mean=True,with_std=False) #sin sacar varianza
df_train = pd.read_csv("Datos_split/koi_light_curves_train.csv",header=None)

X_train = np.nan_to_num(df_train.values)
#fourier
Xtrain_fourier = np.abs(np.fft.fft(X_train))
std.fit(Xtrain_fourier)
Xtrain_std = std.transform(Xtrain_fourier)
print("CenterScaler entrenado")

df_val = pd.read_csv("Datos_split/koi_light_curves_val.csv",header=None)

X_val = np.nan_to_num(df_val.values)
#fourier
Xval_fourier = np.abs(np.fft.fft(X_val))
Xval_std = std.transform(Xval_fourier)
print("VAL escalado y fourier transformado")

df_test = pd.read_csv("Datos_split/koi_light_curves_test.csv",header=None)

X_test = np.nan_to_num(df_test.values)
#fourier
Xtest_fourier = np.abs(np.fft.fft(X_test))
Xtest_std = std.transform(Xtest_fourier)
print("TEST escalado y fourier transformado")

del df_train
del df_val
del df_test
# Out:
# CenterScaler entrenado
# VAL escalado y fourier transformado
# TEST escalado y fourier transformado

# %%
from sklearn.decomposition import FastICA
   
dims= [5,10,15,20,50]

for d in dims:
    model = FastICA(d)
    
    ##################### TRAIN #####################
    model.fit(Xtrain_std)
    print('ICA entrenado con', d, 'caracteristicas')

    #################### ARRIBA ENTRENAMIENTO ###########
    doc_tr = open('koi_light_curves_FICA_train'+str(d)+'.csv', 'w') 
    tr = csv.writer(doc_tr)

    tr.writerows(model.transform(Xtrain_std))
    doc_tr.close()
    print('Generacion de CSV Train', d)
    
    ##################### VAL ########################
    doc_val = open('koi_light_curves_FICA_val'+str(d)+'.csv', 'w') 
    val = csv.writer(doc_val)    
    
    val.writerows(model.transform(Xval_std))
    doc_val.close()
    print('Generacion de CSV Val', d)

    ##################### TEST ########################
    doc_test = open('koi_light_curves_FICA_test'+str(d)+'.csv', 'w') 
    test = csv.writer(doc_test)    

    test.writerows(model.transform(Xtest_std))
    doc_test.close()
    print('Generacion de CSV Test', d)
    
print('Proceso de reducción de dimensionalidad completo')
# Out:
# ICA entrenado con 5 caracteristicas
# Generacion de CSV Train 5
# Generacion de CSV Val 5
# Generacion de CSV Test 5
# ICA entrenado con 10 caracteristicas
# Generacion de CSV Train 10
# Generacion de CSV Val 10
# Generacion de CSV Test 10
# ICA entrenado con 15 caracteristicas
# Generacion de CSV Train 15
# Generacion de CSV Val 15
# Generacion de CSV Test 15
# ICA entrenado con 20 caracteristicas
# Generacion de CSV Train 20
# Generacion de CSV Val 20
# Generacion de CSV Test 20
# ICA entrenado con 50 caracteristicas
# Generacion de CSV Train 50
# Generacion de CSV Val 50
# Generacion de CSV Test 50
# Proceso de reducción de dimensionalidad completo

# %% [markdown]
# ## Sobre Softresampled-fourier

# %%
std = StandardScaler(with_mean=True,with_std=False) #sin sacar varianza
df_train = pd.read_csv("Resample/koi_light_curves_softresample_train.csv",header=None)

X_train = np.nan_to_num(df_train.values)
#fourier
Xtrain_fourier = np.abs(np.fft.fft(X_train))
std.fit(Xtrain_fourier)
Xtrain_std = std.transform(Xtrain_fourier)
print("CenterScaler entrenado")

df_val = pd.read_csv("Resample/koi_light_curves_softresample_val.csv",header=None)

X_val = np.nan_to_num(df_val.values)
#fourier
Xval_fourier = np.abs(np.fft.fft(X_val))
Xval_std = std.transform(Xval_fourier)
print("VAL escalado y fourier transformado")

df_test = pd.read_csv("Resample/koi_light_curves_softresample_test.csv",header=None)

X_test = np.nan_to_num(df_test.values)
#fourier
Xtest_fourier = np.abs(np.fft.fft(X_test))
Xtest_std = std.transform(Xtest_fourier)
print("TEST escalado y fourier transformado")

del df_train
del df_val
del df_test
# Out:
# CenterScaler entrenado
# VAL escalado y fourier transformado
# TEST escalado y fourier transformado

# %%
from sklearn.decomposition import FastICA
   
dims= [5,10,15,20,50]

for d in dims:
    model = FastICA(d)
    
    ##################### TRAIN #####################
    model.fit(Xtrain_std)
    print('ICA entrenado con', d, 'caracteristicas')

    #################### ARRIBA ENTRENAMIENTO ###########
    doc_tr = open('koi_light_curves_FICA_softresampled_train'+str(d)+'.csv', 'w') 
    tr = csv.writer(doc_tr)

    tr.writerows(model.transform(Xtrain_std))
    doc_tr.close()
    print('Generacion de CSV Train', d)
    
    ##################### VAL ########################
    doc_val = open('koi_light_curves_FICA_softresampled_val'+str(d)+'.csv', 'w') 
    val = csv.writer(doc_val)    
    
    val.writerows(model.transform(Xval_std))
    doc_val.close()
    print('Generacion de CSV Val', d)

    ##################### TEST ########################
    doc_test = open('koi_light_curves_FICA_softresampled_test'+str(d)+'.csv', 'w') 
    test = csv.writer(doc_test)    

    test.writerows(model.transform(Xtest_std))
    doc_test.close()
    print('Generacion de CSV Test', d)
    
print('Proceso de reducción de dimensionalidad completo')
# Out:
# ICA entrenado con 5 caracteristicas
# Generacion de CSV Train 5
# Generacion de CSV Val 5
# Generacion de CSV Test 5
# ICA entrenado con 10 caracteristicas
# Generacion de CSV Train 10
# Generacion de CSV Val 10
# Generacion de CSV Test 10
# ICA entrenado con 15 caracteristicas
# Generacion de CSV Train 15
# Generacion de CSV Val 15
# Generacion de CSV Test 15
# ICA entrenado con 20 caracteristicas
# Generacion de CSV Train 20
# Generacion de CSV Val 20
# Generacion de CSV Test 20
# ICA entrenado con 50 caracteristicas
# Generacion de CSV Train 50
# Generacion de CSV Val 50
# Generacion de CSV Test 50
# Proceso de reducción de dimensionalidad completo

# %% [markdown]
# ## Sobre resampled-fourier

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
import pandas as pd

std = StandardScaler(with_mean=True,with_std=False) #sin sacar varianza
df_train = pd.read_csv("Resample/koi_light_curves_resample_train.csv",header=None)

X_train = df_train.values
#fourier
Xtrain_fourier = np.abs(np.fft.fft(X_train))
std.fit(Xtrain_fourier)
Xtrain_std = std.transform(Xtrain_fourier)
print("CenterScaler entrenado")

df_val = pd.read_csv("Resample/koi_light_curves_resample_val.csv",header=None)

X_val = df_val.values
#fourier
Xval_fourier = np.abs(np.fft.fft(X_val))
Xval_std = std.transform(Xval_fourier)
print("VAL escalado y fourier transformado")

df_test = pd.read_csv("Resample/koi_light_curves_resample_test.csv",header=None)

X_test = df_test.values
#fourier
Xtest_fourier = np.abs(np.fft.fft(X_test))
Xtest_std = std.transform(Xtest_fourier)
print("TEST escalado y fourier transformado")

del df_train
del df_val
del df_test
# Out:
# CenterScaler entrenado
# VAL escalado y fourier transformado
# TEST escalado y fourier transformado

# %%
from sklearn.decomposition import FastICA
import csv

dims= [5,10,15,20,50]

for d in dims:
    model = FastICA(d)
    
    ##################### TRAIN #####################
    model.fit(Xtrain_std)
    print('ICA entrenado con', d, 'caracteristicas')

    #################### ARRIBA ENTRENAMIENTO ###########
    doc_tr = open('koi_light_curves_FICA_resampled_train'+str(d)+'.csv', 'w') 
    tr = csv.writer(doc_tr)

    tr.writerows(model.transform(Xtrain_std))
    doc_tr.close()
    print('Generacion de CSV Train', d)
    
    ##################### VAL ########################
    doc_val = open('koi_light_curves_FICA_resampled_val'+str(d)+'.csv', 'w') 
    val = csv.writer(doc_val)    
    
    val.writerows(model.transform(Xval_std))
    doc_val.close()
    print('Generacion de CSV Val', d)

    ##################### TEST ########################
    doc_test = open('koi_light_curves_FICA_resampled_test'+str(d)+'.csv', 'w') 
    test = csv.writer(doc_test)    

    test.writerows(model.transform(Xtest_std))
    doc_test.close()
    print('Generacion de CSV Test', d)
    
print('Proceso de reducción de dimensionalidad completo')
# Out:
# ICA entrenado con 5 caracteristicas
# Generacion de CSV Train 5
# Generacion de CSV Val 5
# Generacion de CSV Test 5
# ICA entrenado con 10 caracteristicas
# Generacion de CSV Train 10
# Generacion de CSV Val 10
# Generacion de CSV Test 10
# ICA entrenado con 15 caracteristicas
# Generacion de CSV Train 15
# Generacion de CSV Val 15
# Generacion de CSV Test 15
# ICA entrenado con 20 caracteristicas
# Generacion de CSV Train 20
# Generacion de CSV Val 20
# Generacion de CSV Test 20
# ICA entrenado con 50 caracteristicas
# Generacion de CSV Train 50
# Generacion de CSV Val 50
# Generacion de CSV Test 50
# Proceso de reducción de dimensionalidad completo

# %% [markdown]
# ## linea de tendencia-fourier

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
import pandas as pd

std = StandardScaler(with_mean=True,with_std=False) #sin sacar varianza
df_train = pd.read_csv("Linea_Tendencia/koi_light_curves_completed_train.csv",header=None)

X_train = df_train.values
#fourier
Xtrain_fourier = np.abs(np.fft.fft(X_train))
std.fit(Xtrain_fourier)
Xtrain_std = std.transform(Xtrain_fourier)
print("CenterScaler entrenado")

df_val = pd.read_csv("Linea_Tendencia/koi_light_curves_completed_val.csv",header=None)

X_val = df_val.values
#fourier
Xval_fourier = np.abs(np.fft.fft(X_val))
Xval_std = std.transform(Xval_fourier)
print("VAL escalado y fourier transformado")

df_test = pd.read_csv("Linea_Tendencia/koi_light_curves_completed_test.csv",header=None)

X_test = df_test.values
#fourier
Xtest_fourier = np.abs(np.fft.fft(X_test))
Xtest_std = std.transform(Xtest_fourier)
print("TEST escalado y fourier transformado")

del df_train
del df_val
del df_test
# Out:
# CenterScaler entrenado
# VAL escalado y fourier transformado
# TEST escalado y fourier transformado

# %%
from sklearn.decomposition import FastICA
import csv

dims= [5,10,15,20,50]

for d in dims:
    model = FastICA(d)
    
    ##################### TRAIN #####################
    model.fit(Xtrain_std)
    print('ICA entrenado con', d, 'caracteristicas')

    #################### ARRIBA ENTRENAMIENTO ###########
    doc_tr = open('koi_light_curves_FICA_completed_train'+str(d)+'.csv', 'w') 
    tr = csv.writer(doc_tr)

    tr.writerows(model.transform(Xtrain_std))
    doc_tr.close()
    print('Generacion de CSV Train', d)
    
    ##################### VAL ########################
    doc_val = open('koi_light_curves_FICA_completed_val'+str(d)+'.csv', 'w') 
    val = csv.writer(doc_val)    
    
    val.writerows(model.transform(Xval_std))
    doc_val.close()
    print('Generacion de CSV Val', d)

    ##################### TEST ########################
    doc_test = open('koi_light_curves_FICA_completed_test'+str(d)+'.csv', 'w') 
    test = csv.writer(doc_test)    

    test.writerows(model.transform(Xtest_std))
    doc_test.close()
    print('Generacion de CSV Test', d)
    
print('Proceso de reducción de dimensionalidad completo')
# Out:
# ICA entrenado con 5 caracteristicas
# Generacion de CSV Train 5
# Generacion de CSV Val 5
# Generacion de CSV Test 5
# ICA entrenado con 10 caracteristicas
# Generacion de CSV Train 10
# Generacion de CSV Val 10
# Generacion de CSV Test 10
# ICA entrenado con 15 caracteristicas
# Generacion de CSV Train 15
# Generacion de CSV Val 15
# Generacion de CSV Test 15
# ICA entrenado con 20 caracteristicas
# Generacion de CSV Train 20
# Generacion de CSV Val 20
# Generacion de CSV Test 20
# ICA entrenado con 50 caracteristicas
# Generacion de CSV Train 50
# Generacion de CSV Val 50
# Generacion de CSV Test 50
# Proceso de reducción de dimensionalidad completo

# %% [markdown]
# ## Sobre linea de tendencia (Full)-fourier

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
import pandas as pd

std = StandardScaler(with_mean=True,with_std=False) #sin sacar varianza
df_train = pd.read_csv("Linea_Tendencia/koi_light_curves_full_train.csv",header=None)

X_train = df_train.values
#fourier
Xtrain_fourier = np.abs(np.fft.fft(X_train))
std.fit(Xtrain_fourier)
Xtrain_std = std.transform(Xtrain_fourier)
print("CenterScaler entrenado")

df_val = pd.read_csv("Linea_Tendencia/koi_light_curves_full_val.csv",header=None)

X_val = df_val.values
#fourier
Xval_fourier = np.abs(np.fft.fft(X_val))
Xval_std = std.transform(Xval_fourier)
print("VAL escalado y fourier transformado")

df_test = pd.read_csv("Linea_Tendencia/koi_light_curves_full_test.csv",header=None)

X_test = df_test.values
#fourier
Xtest_fourier = np.abs(np.fft.fft(X_test))
Xtest_std = std.transform(Xtest_fourier)
print("TEST escalado y fourier transformado")

del df_train
del df_val
del df_test
# Out:
# CenterScaler entrenado
# VAL escalado y fourier transformado
# TEST escalado y fourier transformado

# %%
from sklearn.decomposition import FastICA
import csv

dims= [5,10,15,20,50]

for d in dims:
    model = FastICA(d)
    
    ##################### TRAIN #####################
    model.fit(Xtrain_std)
    print('ICA entrenado con', d, 'caracteristicas')

    #################### ARRIBA ENTRENAMIENTO ###########
    doc_tr = open('koi_light_curves_FICA_full_train'+str(d)+'.csv', 'w') 
    tr = csv.writer(doc_tr)

    tr.writerows(model.transform(Xtrain_std))
    doc_tr.close()
    print('Generacion de CSV Train', d)
    
    ##################### VAL ########################
    doc_val = open('koi_light_curves_FICA_full_val'+str(d)+'.csv', 'w') 
    val = csv.writer(doc_val)    
    
    val.writerows(model.transform(Xval_std))
    doc_val.close()
    print('Generacion de CSV Val', d)

    ##################### TEST ########################
    doc_test = open('koi_light_curves_FICA_full_test'+str(d)+'.csv', 'w') 
    test = csv.writer(doc_test)    

    test.writerows(model.transform(Xtest_std))
    doc_test.close()
    print('Generacion de CSV Test', d)
    
print('Proceso de reducción de dimensionalidad completo')
# Out:
# ICA entrenado con 5 caracteristicas
# Generacion de CSV Train 5
# Generacion de CSV Val 5
# Generacion de CSV Test 5
# ICA entrenado con 10 caracteristicas
# Generacion de CSV Train 10
# Generacion de CSV Val 10
# Generacion de CSV Test 10
# ICA entrenado con 15 caracteristicas
# Generacion de CSV Train 15
# Generacion de CSV Val 15
# Generacion de CSV Test 15
# ICA entrenado con 20 caracteristicas
# Generacion de CSV Train 20
# Generacion de CSV Val 20
# Generacion de CSV Test 20
# ICA entrenado con 50 caracteristicas
# Generacion de CSV Train 50
# Generacion de CSV Val 50
# Generacion de CSV Test 50
# Proceso de reducción de dimensionalidad completo

# %% [markdown]
# ### Sobre light curves sin nan

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
import csv
import pandas as pd


std = StandardScaler(with_mean=True,with_std=False) #sin sacar varianza
df_train = pd.read_csv("Datos_split_true/koi_light_curves_true_train.csv",header=None)

X_train = np.nan_to_num(df_train.values)
#fourier
Xtrain_fourier = np.abs(np.fft.fft(X_train))
std.fit(Xtrain_fourier)
Xtrain_std = std.transform(Xtrain_fourier)
print("CenterScaler entrenado")

df_val = pd.read_csv("Datos_split_true/koi_light_curves_true_val.csv",header=None)

X_val = np.nan_to_num(df_val.values)
#fourier
Xval_fourier = np.abs(np.fft.fft(X_val))
Xval_std = std.transform(Xval_fourier)
print("VAL escalado y fourier transformado")

df_test = pd.read_csv("Datos_split_true/koi_light_curves_true_test.csv",header=None)

X_test = np.nan_to_num(df_test.values)
#fourier
Xtest_fourier = np.abs(np.fft.fft(X_test))
Xtest_std = std.transform(Xtest_fourier)
print("TEST escalado y fourier transformado sin NaN")

del df_train
del df_val
del df_test
# Out:
# CenterScaler entrenado
# VAL escalado y fourier transformado
# TEST escalado y fourier transformado sin NaN

# %%
from sklearn.decomposition import FastICA
   
dims= [5,10,15,20,50]

for d in dims:
    model = FastICA(d)
    
    ##################### TRAIN #####################
    model.fit(Xtrain_std)
    print('ICA entrenado con', d, 'caracteristicas')

    #################### ARRIBA ENTRENAMIENTO ###########
    doc_tr = open('FICA_data_SN/koi_light_curves_FICA_true_train'+str(d)+'.csv', 'w') 
    tr = csv.writer(doc_tr)

    tr.writerows(model.transform(Xtrain_std))
    doc_tr.close()
    print('Generacion de CSV Train', d)
    
    ##################### VAL ########################
    doc_val = open('FICA_data_SN/koi_light_curves_FICA_true_val'+str(d)+'.csv', 'w') 
    val = csv.writer(doc_val)    
    
    val.writerows(model.transform(Xval_std))
    doc_val.close()
    print('Generacion de CSV Val', d)

    ##################### TEST ########################
    doc_test = open('FICA_data_SN/koi_light_curves_FICA_true_test'+str(d)+'.csv', 'w') 
    test = csv.writer(doc_test)    

    test.writerows(model.transform(Xtest_std))
    doc_test.close()
    print('Generacion de CSV Test', d)
    
print('Proceso de reducción de dimensionalidad completo')
# Out:
# ICA entrenado con 5 caracteristicas
# Generacion de CSV Train 5
# Generacion de CSV Val 5
# Generacion de CSV Test 5
# ICA entrenado con 10 caracteristicas
# Generacion de CSV Train 10
# Generacion de CSV Val 10
# Generacion de CSV Test 10
# ICA entrenado con 15 caracteristicas
# Generacion de CSV Train 15
# Generacion de CSV Val 15
# Generacion de CSV Test 15
# ICA entrenado con 20 caracteristicas
# Generacion de CSV Train 20
# Generacion de CSV Val 20
# Generacion de CSV Test 20
# ICA entrenado con 50 caracteristicas
# Generacion de CSV Train 50
# Generacion de CSV Val 50
# Generacion de CSV Test 50
# Proceso de reducción de dimensionalidad completo
